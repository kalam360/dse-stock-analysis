# %%
import pandas as pd
import missingno as msno
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/total_daily_data.csv', header = 0)
# Out:
# /Users/xebra/Desktop/Projects/quantitative-finance/portfolio-analysis/sy-portfolio/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.set_index(pd.to_datetime(df['date'])).drop('date', axis = 1)

# %%
df['2019-01-01']
# Out:
#                 symbol     open     high      low    close      volume
# date
# 2019-01-01      00DS30  1880.78  1911.37  1880.78  1908.20  53017420.0
# 2019-01-01      00DSES  1232.82  1247.50  1232.82  1245.80  53017420.0
# 2019-01-01      00DSEX  5385.64  5474.50  5385.64  5465.25  53017420.0
# 2019-01-01     01.Bank    25.64    26.03    25.32    25.81  1031521.37
# 2019-01-01   02.Cement   117.19   118.34    116.3   117.59    96386.86
# ...                ...      ...      ...      ...      ...         ...
# 2019-01-01  WMSHIPYARD    19.80    21.00     19.8    20.70   1659523.0
# 2019-01-01         YPL    13.20    13.60     13.1    13.40     65029.0
# 2019-01-01  ZAHEENSPIN    11.40    11.50     11.0    11.40    316451.0
# 2019-01-01    ZAHINTEX    11.00    11.30     10.8    11.20    129579.0
# 2019-01-01  ZEALBANGLA    43.90    44.00     43.3    43.40      4220.0
#
# [368 rows x 6 columns]

# %%
msno.matrix(df)

# %%
df.symbol.unique()
# Out:
# array(['00DS30', '00DSES', '00DSEX', '01.Bank', '02.Cement',
#        '03.Ceramics_Sector', '04.Engineering',
#        '05.Financial_Institutions', '06.Food_&_Allied', '07.Fuel_&_Power',
#        '08.Insurance', '09.IT_Sector', '10.Jute', '11.Miscellaneous',
#        '12.Mutual_Funds', '13.Paper_&_Printing',
#        '14.Pharmaceuticals_&_Chemicals', '15.Services_&_Real_Estate',
#        '16.Tannery_Industries', '17.Telecommunication', '18.Textile',
#        '19.Travel_&_Leisure', '1JANATAMF', '1STPRIMFMF', '20.Bond',
#        'AAMRANET', 'AAMRATECH', 'ABB1STMF', 'ABBANK', 'ACFL', 'ACI',
#        'ACIFORMULA', 'ACMELAB', 'ACTIVEFINE', 'ADVENT', 'AFCAGRO',
#        'AFTABAUTO', 'AGNISYSL', 'AGRANINS', 'AIBL1STIMF', 'AIL',
#        'ALARABANK', 'AL-HAJTEX', 'ALIF', 'ALLTEX', 'AMANFEED', 'AMBEEPHA',
#        'AMCL(PRAN)', 'ANLIMAYARN', 'ANWARGALV', 'APEXFOODS', 'APEXFOOT',
#        'APEXSPINN', 'APEXTANRY', 'APOLOISPAT', 'ARAMIT', 'ARAMITCEM',
#        'ARGONDENIM', 'ASIAINS', 'ASIAPACINS', 'ATCSLGF', 'ATLASBANG',
#        'AZIZPIPES', 'BANGAS', 'BANKASIA', 'BARKAPOWER', 'BATASHOE',
#        'BATBC', 'BAYLEASING', 'BBS', 'BBSCABLES', 'BDAUTOCA', 'BDCOM',
#        'BDFINANCE', 'BDLAMPS', 'BDTHAI', 'BDWELDING', 'BEACHHATCH',
#        'BEACONPHAR', 'BENGALWTL', 'BERGERPBL', 'BEXIMCO', 'BGIC', 'BIFC',
#        'BNICL', 'BPML', 'BRACBANK', 'BSC', 'BSCCL', 'BSRMLTD',
#        'BSRMSTEEL', 'BXPHARMA', 'BXSYNTH', 'CAPMBDBLMF', 'CAPMIBBLMF',
#        'CENTRALINS', 'CENTRALPHL', 'CITYBANK', 'CITYGENINS', 'CNATEX',
#        'CONFIDCEM', 'CONTININS', 'CVOPRL', 'DACCADYE', 'DAFODILCOM',
#        'DBH', 'DBH1STMF', 'DELTALIFE', 'DELTASPINN', 'DESCO',
#        'DESHBANDHU', 'DHAKABANK', 'DHAKAINS', 'DOREENPWR', 'DS30', 'DSES',
#        'DSEX', 'DSHGARME', 'DSSL', 'DULAMIACOT', 'DUTCHBANGL',
#        'EASTERNINS', 'EASTLAND', 'EASTRNLUB', 'EBL', 'EBL1STMF',
#        'EBLNRBMF', 'ECABLES', 'EHL', 'EMERALDOIL', 'ENVOYTEX', 'ETL',
#        'EXIM1STMF', 'EXIMBANK', 'FAMILYTEX', 'FARCHEM', 'FAREASTFIN',
#        'FAREASTLIF', 'FASFIN', 'FBFIF', 'FEDERALINS', 'FEKDIL',
#        'FINEFOODS', 'FIRSTFIN', 'FIRSTSBANK', 'FORTUNE', 'FUWANGCER',
#        'FUWANGFOOD', 'GBBPOWER', 'GEMINISEA', 'GENEXIL', 'GENNEXT',
#        'GHAIL', 'GHCL', 'GLAXOSMITH', 'GLOBALINS', 'GOLDENSON', 'GP',
#        'GPHISPAT', 'GQBALLPEN', 'GRAMEENS2', 'GREENDELMF', 'GREENDELT',
#        'GSPFINANCE', 'HAKKANIPUL', 'HEIDELBCEM', 'HFL', 'HRTEX',
#        'HWAWELLTEX', 'IBBLPBOND', 'IBNSINA', 'IBP', 'ICB', 'ICB3RDNRB',
#        'ICBAGRANI1', 'ICBAMCL2ND', 'ICBEPMF1S1', 'ICBIBANK', 'ICBSONALI1',
#        'IDLC', 'IFADAUTOS', 'IFIC', 'IFIC1STMF', 'IFILISLMF1', 'ILFSL',
#        'IMAMBUTTON', 'INTECH', 'INTRACO', 'IPDC', 'ISLAMIBANK',
#        'ISLAMICFIN', 'ISLAMIINS', 'ISNLTD', 'ITC', 'JAMUNABANK',
#        'JAMUNAOIL', 'JANATAINS', 'JMISMDL', 'JUTESPINN', 'KARNAPHULI',
#        'KAY&QUE', 'KBPPWBIL', 'KDSALTD', 'KEYACOSMET', 'KOHINOOR', 'KPCL',
#        'KPPL', 'KTL', 'LANKABAFIN', 'LEGACYFOOT', 'LHBL', 'LIBRAINFU',
#        'LINDEBD', 'LRGLOBMF1', 'MAKSONSPIN', 'MALEKSPIN', 'MARICO',
#        'MATINSPINN', 'MBL1STMF', 'MEGCONMILK', 'MEGHNACEM', 'MEGHNALIFE',
#        'MEGHNAPET', 'MERCANBANK', 'MERCINS', 'METROSPIN', 'MHSML',
#        'MICEMENT', 'MIDASFIN', 'MIRACLEIND', 'MITHUNKNIT', 'MJLBD',
#        'MLDYEING', 'MONNOCERA', 'MONNOSTAF', 'MPETROLEUM', 'MTB',
#        'NAHEEACP', 'NATLIFEINS', 'NAVANACNG', 'NBL', 'NCCBANK',
#        'NCCBLMF1', 'NFML', 'NHFIL', 'NITOLINS', 'NLI1STMF', 'NORTHERN',
#        'NORTHRNINS', 'NPOLYMAR', 'NTC', 'NTLTUBES', 'NURANI', 'OAL',
#        'OIMEX', 'OLYMPIC', 'ONEBANKLTD', 'ORIONINFU', 'ORIONPHARM',
#        'PADMALIFE', 'PADMAOIL', 'PARAMOUNT', 'PDL', 'PENINSULA',
#        'PEOPLESINS', 'PF1STMF', 'PHARMAID', 'PHENIXINS', 'PHOENIXFIN',
#        'PHPMF1', 'PIONEERINS', 'PLFSL', 'POPULAR1MF', 'POPULARLIF',
#        'POWERGRID', 'PRAGATIINS', 'PRAGATILIF', 'PREMIERBAN',
#        'PREMIERCEM', 'PREMIERLEA', 'PRIME1ICBA', 'PRIMEBANK', 'PRIMEFIN',
#        'PRIMEINSUR', 'PRIMELIFE', 'PRIMETEX', 'PROGRESLIF', 'PROVATIINS',
#        'PTL', 'PUBALIBANK', 'PURABIGEN', 'QUASEMIND', 'QUEENSOUTH',
#        'RAHIMTEXT', 'RAKCERAMIC', 'RANFOUNDRY', 'RDFOOD', 'RECKITTBEN',
#        'REGENTTEX', 'RELIANCE1', 'RELIANCINS', 'RENATA', 'RENWICKJA',
#        'REPUBLIC', 'RNSPIN', 'RSRMSTEEL', 'RUPALIBANK', 'RUPALIINS',
#        'RUPALILIFE', 'SAFKOSPINN', 'SAIFPOWER', 'SAIHAMCOT', 'SAIHAMTEX',
#        'SALAMCRST', 'SALVOCHEM', 'SAMATALETH', 'SAMORITA', 'SANDHANINS',
#        'SAPORTL', 'SAVAREFR', 'SEBL1STMF', 'SEMLIBBLSF', 'SEMLLECMF',
#        'SHAHJABANK', 'SHASHADNIM', 'SHEPHERD', 'SHURWID', 'SHYAMPSUG',
#        'SIBL', 'SILVAPHL', 'SIMTEX', 'SINGERBD', 'SINOBANGLA', 'SKTRIMS',
#        'SONALIANSH', 'SONARBAINS', 'SONARGAON', 'SOUTHEASTB',
#        'SPCERAMICS', 'SPCL', 'SQUARETEXT', 'SQURPHARMA', 'SSSTEEL',
#        'STANCERAM', 'STANDARINS', 'STANDBANKL', 'STYLECRAFT',
#        'SUMITPOWER', 'SUNLIFEINS', 'TAKAFULINS', 'TALLUSPIN', 'TITASGAS',
#        'TOSRIFA', 'TRUSTB1MF', 'TRUSTBANK', 'TUNGHAI', 'UCB', 'UNIONCAP',
#        'UNIQUEHRL', 'UNITEDAIR', 'UNITEDFIN', 'UNITEDINS', 'UPGDCL',
#        'USMANIAGL', 'UTTARABANK', 'UTTARAFIN', 'VAMLBDMF1', 'VAMLRBBF',
#        'VFSTDL', 'WATACHEM', 'WMSHIPYARD', 'YPL', 'ZAHEENSPIN',
#        'ZAHINTEX', 'ZEALBANGLA', '00DSEGEN', '1STBSRS', '1STICB',
#        '2NDICB', '3RDICB', '4THICB', '5THICB', '6THICB', '7THICB',
#        '8THICB', 'AIMS1STMF', 'ALAMINCHEM', 'ALPHATOBA', 'AMAMSEAFD',
#        'APEXADELFT', 'APEXWEAV', 'ASHRAFTEX', 'BANGLAPRO', 'BCIL',
#        'BDDYE', 'BDHOTELS', 'BDLUGGAGE', 'BDONLINE', 'BDPLANT',
#        'BDZIPPER', 'BEMCO', 'BENGALBISC', 'BENGALFINE', 'BEXTEX',
#        'BIONICFOOD', 'BLTC', 'BOC', 'BXFISHERY', 'CHICTEX', 'CMCKAMAL',
#        'CTGVEG', 'DANDYDYE', 'DHAKAFISH', 'DYNAMICTEX', 'EAGLESTAR',
#        'EXCELSHOE', 'FIDELASSET', 'FLEASEINT', 'GACHIHATA', 'GBJVFOOD',
#        'GRAMEEN1', 'GULFOODS', 'HILLPLANT', 'HIMADRI', 'ICB1STNRB',
#        'ICB2NDNRB', 'ICBAMCL1ST', 'ICBISLAMIC', 'KEYADETERG',
#        'LAFSURCEML', 'LEXCO', 'MAQENTER', 'MAQPAPER', 'MEGHNASHRM',
#        'METALEXCR', 'MHOSSAIN', 'MITATEX', 'MODERNCEM', 'MODERNDYE',
#        'MODERNIND', 'MONAFOOD', 'MONNOFABR', 'MONNOJTX', 'MONOSPOOL',
#        'MTBL', 'NILOYCEM', 'PADMACEM', 'PADMAPRINT', 'PAPERPROC',
#        'PERFUMCHM', 'PETROSYNTH', 'PHARMACO', 'PHENIXLETH', 'QSMDRYCELL',
#        'QSMSILK', 'QSMTEX', 'RAHIMAFOOD', 'RAHMANCHEM', 'RANGAFOOD',
#        'RASPIT', 'RASPITDATA', 'ROSEHEAVEN', 'SAJIBKNIT', 'SALEHCARPT',
#        'SHINEPUKUR', 'SOCIALINV', 'SONALIPAPR', 'SREEPURTEX', 'TAMIJTEX',
#        'TBL', 'TRIPTI', 'TULIPDAIRY', 'UCBL', 'ULC', 'WONDERTOYS',
#        'ARAMITCEM ', 'AZIZPIPES ', 'BDSERVICE', 'BRACSCBOND', 'EASTLAND ',
#        'OLYMPIC ', 'ACIZCBOND', 'BEDL', 'FUWANGCER ', 'SPPCL',
#        'ESQUIRENIT', 'SEMLFBSLGF', 'BDBUILDING', 'NEWLINE', 'RUNNERAUTO',
#        'OCL', 'COPPERTECH', 'SEAPEARL', 'SILCOPHL'], dtype=object)

# %%
df_it = df[df['symbol'] == '09.IT_Sector']

# %%
df_it.index.unique()
# Out:
# DatetimeIndex(['2019-02-03', '2019-02-04', '2019-02-05', '2019-02-06',
#                '2019-02-07', '2019-02-10', '2019-02-11', '2019-02-12',
#                '2019-02-13', '2019-02-14',
#                ...
#                '2019-06-17', '2019-06-18', '2019-06-19', '2019-06-20',
#                '2019-06-23', '2019-06-24', '2019-06-25', '2019-06-26',
#                '2019-06-27', '2019-06-30'],
#               dtype='datetime64[ns]', name='date', length=561, freq=None)

# %%
df_it['close'].plot()

# %%
dates = pd.to_datetime(["2019-08-01", "2018-08-01", "2017-08-01", "2016-08-01","2015-08-02", "2014-08-03", "2013-08-01", "2012-08-01", "2011-08-01", "2010-08-01", "2009-08-02"])

# %%
dates[5]
# Out:
# Timestamp('2014-08-03 00:00:00')

# %% [markdown]
#     df_returns['2y_r'] = ((df_each[dates[0]]/df_each[dates[2]]) - 1 ) * 100
#     df_returns['3y_r'] = ((df_each[dates[0]]/df_each[dates[3]]) - 1 ) * 100
#     df_returns['4y_r'] = ((df_each[dates[0]]/df_each[dates[4]]) - 1 ) * 100
#     df_returns['5y_r'] = ((df_each[dates[0]]/df_each[dates[5]]) - 1 ) * 100
#     df_returns['6y_r'] = ((df_each[dates[0]]/df_each[dates[6]]) - 1 ) * 100
#     df_returns['7y_r'] = ((df_each[dates[0]]/df_each[dates[7]]) - 1 ) * 100
#     df_returns['8y_r'] = ((df_each[dates[0]]/df_each[dates[8]]) - 1 ) * 100
#     df_returns['9y_r'] = ((df_each[dates[0]]/df_each[dates[9]]) - 1 ) * 100
#     df_returns['10y_r'] = ((df_each[dates[0]]/df_each[dates[10]]) - 1 ) * 100

# %% [markdown]
# df_returns = pd.DataFrame()
# for symbol in df.symbol.unique():
#     print(symbol)
#     df_each = df[df['symbol'] == symbol].close
#     ann_yr_1 = (((df_each[dates[0]]/df_each[dates[1]]) - 1 ) * 100)**(1/1)
#     ann_yr_2 = (((df_each[dates[0]]/df_each[dates[2]]) - 1 ) * 100)**(1/2)
#     ann_yr_3 = (((df_each[dates[0]]/df_each[dates[3]]) - 1 ) * 100)**(1/3)
#     ann_yr_4 = (((df_each[dates[0]]/df_each[dates[4]]) - 1 ) * 100)**(1/4)
#     ann_yr_5 = (((df_each[dates[0]]/df_each[dates[5]]) - 1 ) * 100)**(1/5)
#     ann_yr_6 = (((df_each[dates[0]]/df_each[dates[6]]) - 1 ) * 100)**(1/6)
#     ann_yr_7 = (((df_each[dates[0]]/df_each[dates[7]]) - 1 ) * 100)**(1/7)
#     ann_yr_8 = (((df_each[dates[0]]/df_each[dates[8]]) - 1 ) * 100)**(1/8)
#     ann_yr_9 = (((df_each[dates[0]]/df_each[dates[9]]) - 1 ) * 100)**(1/9)
#     yr_1 = (((df_each[dates[0]]/df_each[dates[1]]) - 1 ) * 100)
#     yr_2 = (((df_each[dates[1]]/df_each[dates[2]]) - 1 ) * 100)
#     yr_3 = (((df_each[dates[2]]/df_each[dates[3]]) - 1 ) * 100)
#     yr_4 = (((df_each[dates[3]]/df_each[dates[4]]) - 1 ) * 100)
#     yr_5 = (((df_each[dates[4]]/df_each[dates[5]]) - 1 ) * 100)
#     yr_6 = (((df_each[dates[5]]/df_each[dates[6]]) - 1 ) * 100)
#     yr_7 = (((df_each[dates[6]]/df_each[dates[7]]) - 1 ) * 100)
#     yr_8 = (((df_each[dates[7]]/df_each[dates[8]]) - 1 ) * 100)
#     yr_9 = (((df_each[dates[8]]/df_each[dates[9]]) - 1 ) * 100)
#     df_returns.append({'_symbol': symbol, 'yr_1': yr_1,
#                    'yr_2': yr_2, 'yr_3': yr_3, 'yr_4': yr_4,
#                    'yr_5': yr_5, 'yr_6': yr_6, 'yr_7': yr_7,
#                    'yr_8': yr_8, 'yr_9': yr_9,
#                    'ann_yr_1': ann_yr_1,
#                    'ann_yr_2': ann_yr_2, 'ann_yr_3': ann_yr_3, 'ann_yr_4': ann_yr_4,
#                    'ann_yr_5': ann_yr_5, 'ann_yr_6': ann_yr_6, 'ann_yr_7': ann_yr_7,
#                    'ann_yr_8': ann_yr_8, 'ann_yr_9': ann_yr_9
#                   }, ignore_index = True)

# %% [markdown]
# symbol = '00DS30'
# dates = pd.to_datetime(["2019-08-01", "2018-08-01", "2017-08-01", "2016-08-01","2015-08-02", "2014-08-03","2013-08-01", "2012-08-01", "2011-08-01", "2010-08-01", "2009-08-02"])
# df_returns = pd.DataFrame()
# df_each = df[df['symbol'] == symbol].close
# ann_yr_1 = (((df_each[dates[0]]/df_each[dates[1]]) - 1 ) * 100)**(1/1)
# ann_yr_2 = (((df_each[dates[0]]/df_each[dates[2]]) - 1 ) * 100)**(1/2)
# ann_yr_3 = (((df_each[dates[0]]/df_each[dates[3]]) - 1 ) * 100)**(1/3)
# ann_yr_4 = (((df_each[dates[0]]/df_each[dates[4]]) - 1 ) * 100)**(1/4)
# ann_yr_5 = (((df_each[dates[0]]/df_each[dates[5]]) - 1 ) * 100)**(1/5)
# ann_yr_6 = (((df_each[dates[0]]/df_each[dates[6]]) - 1 ) * 100)**(1/6)
# ann_yr_7 = (((df_each[dates[0]]/df_each[dates[7]]) - 1 ) * 100)**(1/7)
# ann_yr_8 = (((df_each[dates[0]]/df_each[dates[8]]) - 1 ) * 100)**(1/8)
# ann_yr_9 = (((df_each[dates[0]]/df_each[dates[9]]) - 1 ) * 100)**(1/9)
# yr_1 = (((df_each[dates[0]]/df_each[dates[1]]) - 1 ) * 100)
# yr_2 = (((df_each[dates[1]]/df_each[dates[2]]) - 1 ) * 100)
# yr_3 = (((df_each[dates[2]]/df_each[dates[3]]) - 1 ) * 100)
# yr_4 = (((df_each[dates[3]]/df_each[dates[4]]) - 1 ) * 100)
# yr_5 = (((df_each[dates[4]]/df_each[dates[5]]) - 1 ) * 100)
# yr_6 = (((df_each[dates[5]]/df_each[dates[6]]) - 1 ) * 100)
# yr_7 = (((df_each[dates[6]]/df_each[dates[7]]) - 1 ) * 100)
# yr_8 = (((df_each[dates[7]]/df_each[dates[8]]) - 1 ) * 100)
# yr_9 = (((df_each[dates[8]]/df_each[dates[9]]) - 1 ) * 100)
# df_returns.append({'_symbol': symbol, 'yr_1': yr_1,
#                    'yr_2': yr_2, 'yr_3': yr_3, 'yr_4': yr_4,
#                    'yr_5': yr_5, 'yr_6': yr_6, 'yr_7': yr_7,
#                    'yr_8': yr_8, 'yr_9': yr_9,
#                    'ann_yr_1': ann_yr_1,
#                    'ann_yr_2': ann_yr_2, 'ann_yr_3': ann_yr_3, 'ann_yr_4': ann_yr_4,
#                    'ann_yr_5': ann_yr_5, 'ann_yr_6': ann_yr_6, 'ann_yr_7': ann_yr_7,
#                    'ann_yr_8': ann_yr_8, 'ann_yr_9': ann_yr_9
#                   }, ignore_index = True)

# %%
df[df['symbol'] == '00DS30'].close.plot()

# %%
df_it = df[df['symbol'] == 'BANGAS'].close.sort_index()

# %%
rf = 8.5 / 360
(((df_it.pct_change(30).mean() - rf )/df_it.pct_change(30).std())) * (12**.5)
# Out:
# 0.26069270038125836

# %%
df_cal.head()
# Out:
#                 symbol   open   high   low  close  volume
# date
# 2014-01-01   CONTININS   29.4   29.7  29.2   29.4   42500
# 2014-01-01   SEBL1STMF    8.0    8.1   7.9    7.9  178500
# 2014-01-01      BANGAS  483.0  483.7   480  480.2   31550
# 2014-01-01  ACTIVEFINE   82.2   86.6  82.2   86.4  322500
# 2014-01-01   ACIZCBOND  910.0  912.5   910  911.0      20

# %%
df_rs = pd.DataFrame(columns = ['Symbol', 'Avg Return', 'Sharpe Ratio', 'Horizon Return', 'Standard Deviation'])
rf = (7/252)
df_cal = df.sort_index()
df_cal =  df_cal['2014-01-01':]
for symbol in df['2019-08-01'].symbol.unique():
    df_each = df_cal[df_cal['symbol'] == symbol].close
    if len(df_each) > 300 :
        sharpe_ratio = (((df_each.pct_change(1).mean() - rf )/df_each.pct_change(1).std())) * (252**.5)
        avg_return = df_each.pct_change(1).mean()*252
        horizon_return = ((df_each.iloc[-1] / df_each.iloc[0])**(1/(len(df_each)/252)) - 1 )
        std = df_each.pct_change(1).std()*(252**.5)
        df_rs = df_rs.append({'Symbol': symbol, 'Avg Return': round(avg_return, 2) , 'Sharpe Ratio': round(sharpe_ratio,2), 'Horizon Return': round(horizon_return,2), 'Standard Deviation': round(std, 2) }, ignore_index = True )

# %%
df_rs = df_rs.sort_values('Sharpe Ratio', ascending = False)

# %%
df_rs.head(50)
# Out:
#                              Symbol  Avg Return  Sharpe Ratio  Horizon Return  \
# 13                 11.Miscellaneous       13.35          0.99            0.19
# 18            16.Tannery_Industries        4.12         -0.67           -0.03
# 19             17.Telecommunication        2.51         -1.65           -0.03
# 358                        WATACHEM        1.58         -1.68            0.61
# 8                  06.Food_&_Allied        1.81         -2.37           -0.14
# 15              13.Paper_&_Printing        1.59         -2.74            0.18
# 17        15.Services_&_Real_Estate        0.97         -2.84           -0.11
# 5                03.Ceramics_Sector        1.55         -3.66            0.80
# 61                        AZIZPIPES        1.60         -4.45            1.90
# 6                    04.Engineering        0.93         -4.74            0.19
# 12                          10.Jute        1.16         -4.84            0.58
# 21              19.Travel_&_Leisure        0.49         -5.87           -0.04
# 20                       18.Textile        0.31         -6.93           -0.18
# 16   14.Pharmaceuticals_&_Chemicals        0.49         -7.44            0.12
# 312                        SAVAREFR        0.45         -8.48            0.17
# 320                       SHYAMPSUG        0.50         -9.28            0.29
# 117                      DULAMIACOT        0.59         -9.49            0.43
# 9                   07.Fuel_&_Power        0.25         -9.59            0.01
# 363                      ZEALBANGLA        0.53         -9.74            0.36
# 147                       GEMINISEA        0.32         -9.94            0.11
# 308                      SAMATALETH        0.45         -9.94            0.27
# 336                      STYLECRAFT        0.26        -10.09           -0.06
# 4                         02.Cement        0.02        -10.11           -0.19
# 43                           ALLTEX        0.26        -10.17            0.06
# 194                       JUTESPINN        0.25        -10.44            0.04
# 55                        ARAMITCEM       -0.61        -10.46           -0.59
# 181                      IMAMBUTTON        0.38        -10.52            0.20
# 241                        NORTHERN        0.80        -10.53            0.87
# 217                       MEGHNAPET        0.27        -10.67            0.08
# 228                       MONNOSTAF        0.56        -10.84            0.37
# 70                         BDAUTOCA        0.56        -10.85            0.47
# 196                         KAY&QUE        0.63        -11.05            0.60
# 214                      MEGCONMILK        0.28        -11.23            0.11
# 204                      LEGACYFOOT        0.37        -11.47            0.22
# 188                          ISNLTD        0.25        -11.85            0.08
# 227                       MONNOCERA        0.49        -12.02            0.41
# 327                       SONARGAON        0.25        -12.31            0.10
# 333                       STANCERAM        0.59        -12.37            0.58
# 314                      SEMLIBBLSF        0.01        -12.48           -0.13
# 285                      QUEENSOUTH        0.07        -12.49           -0.08
# 206                       LIBRAINFU        0.30        -12.66            0.18
# 161                      HAKKANIPUL        0.22        -12.99            0.09
# 76                       BEACHHATCH        0.00        -13.02           -0.13
# 279                      PROGRESLIF        0.09        -13.17           -0.04
# 75                        BDWELDING        0.09        -13.22           -0.04
# 319                         SHURWID        0.02        -13.24           -0.12
# 223                        MIDASFIN       -0.02        -13.36           -0.15
# 295                       RENWICKJA        0.57        -13.38            0.57
# 224                      MIRACLEIND        0.17        -13.39            0.04
# 140                       FINEFOODS        0.23        -13.45            0.11
#
#      Standard Deviation
# 13                 6.40
# 18                 4.30
# 19                 2.73
# 358                3.22
# 8                  2.19
# 15                 1.97
# 17                 2.12
# 5                  1.49
# 61                 1.22
# 6                  1.28
# 12                 1.21
# 21                 1.11
# 20                 0.97
# 16                 0.88
# 312                0.77
# 320                0.70
# 117                0.68
# 9                  0.70
# 363                0.66
# 147                0.67
# 308                0.66
# 336                0.67
# 4                  0.69
# 43                 0.66
# 194                0.65
# 55                 0.73
# 181                0.63
# 241                0.59
# 217                0.63
# 228                0.59
# 70                 0.59
# 196                0.58
# 214                0.60
# 204                0.58
# 188                0.57
# 227                0.54
# 327                0.55
# 333                0.52
# 314                0.56
# 285                0.55
# 206                0.53
# 161                0.52
# 76                 0.54
# 279                0.52
# 75                 0.52
# 319                0.53
# 223                0.53
# 295                0.48
# 224                0.51
# 140                0.50

# %%
df_usman = df[df['symbol'] == 'USMANIAGL']

# %%
df_usclose = df_usman['close'].sort_index()

# %%
df_usclose['2000-01-01':].pct_change(1).mean()*252
# Out:
# 30.349175545010144

# %%
df_wata = df[df['symbol'] == 'WATACHEM'].sort_index()

# %%
df_wata['2012-01-01':].close
# Out:
# date
# 2014-05-15     54.4
# 2014-05-29     59.8
# 2014-06-02    487.1
# 2014-06-03    449.6
# 2014-06-04    412.2
#               ...
# 2019-08-25    521.5
# 2019-08-26    517.9
# 2019-08-27    556.7
# 2019-08-28    587.0
# 2019-08-29    593.7
# Name: close, Length: 1264, dtype: float64

# %% [markdown]
# ## Selecting the Assets

# %% [markdown]
# 'KAY&QUE'
# 'SAVAREFR'
# 'ZEALBANGLA'
# 'NORTHERN'
#
#
# df_asset['KAY&QUE'] = df_cal[df_cal['symbol'] == 'KAY&QUE'].close

# %%
assets = ['KAY&QUE', 'SAVAREFR', 'ZEALBANGLA', 'NORTHERN', 'LEGACYFOOT', 'STANCERAM', 'MONNOCERA', 'DULAMIACOT', 'BDAUTOCA']
df_asset = pd.DataFrame()
for asset in assets:
    df_asset[asset] = df_cal[df_cal['symbol'] == asset].close

# %%
round(df_asset.pct_change().corr(),2)
# Out:
#             KAY&QUE  SAVAREFR  ZEALBANGLA  NORTHERN  LEGACYFOOT  STANCERAM  \
# KAY&QUE        1.00      0.13        0.07      0.09        0.15       0.11
# SAVAREFR       0.13      1.00        0.10      0.10        0.08       0.08
# ZEALBANGLA     0.07      0.10        1.00      0.02        0.11       0.06
# NORTHERN       0.09      0.10        0.02      1.00        0.06       0.05
# LEGACYFOOT     0.15      0.08        0.11      0.06        1.00       0.12
# STANCERAM      0.11      0.08        0.06      0.05        0.12       1.00
# MONNOCERA      0.12      0.09        0.10      0.09        0.35       0.31
# DULAMIACOT     0.12      0.14        0.16      0.05        0.11       0.09
# BDAUTOCA       0.08      0.06        0.08      0.08        0.17       0.13
#
#             MONNOCERA  DULAMIACOT  BDAUTOCA
# KAY&QUE          0.12        0.12      0.08
# SAVAREFR         0.09        0.14      0.06
# ZEALBANGLA       0.10        0.16      0.08
# NORTHERN         0.09        0.05      0.08
# LEGACYFOOT       0.35        0.11      0.17
# STANCERAM        0.31        0.09      0.13
# MONNOCERA        1.00        0.10      0.19
# DULAMIACOT       0.10        1.00      0.05
# BDAUTOCA         0.19        0.05      1.00

# %% [markdown]
# slecting:
#     - NORTHERN
#     - ZEALBANGLA

# %%
df_selected = df_asset[['NORTHERN', 'ZEALBANGLA']]

# %%
df_cal.head()
# Out:
#                 symbol   open   high   low  close  volume
# date
# 2014-01-01   CONTININS   29.4   29.7  29.2   29.4   42500
# 2014-01-01   SEBL1STMF    8.0    8.1   7.9    7.9  178500
# 2014-01-01      BANGAS  483.0  483.7   480  480.2   31550
# 2014-01-01  ACTIVEFINE   82.2   86.6  82.2   86.4  322500
# 2014-01-01   ACIZCBOND  910.0  912.5   910  911.0      20

# %%
df_monthly = round(df_selected.resample('M').mean(), 2)

# %%
df_monthly.head(10)
# Out:
#             NORTHERN  ZEALBANGLA
# date
# 2014-01-31     66.05        8.93
# 2014-02-28     71.00        8.71
# 2014-03-31     79.04        9.06
# 2014-04-30    116.81        9.38
# 2014-05-31    134.00        9.00
# 2014-06-30    123.00        8.49
# 2014-07-31       NaN        7.70
# 2014-08-31    143.00        7.25
# 2014-09-30    144.00        7.38
# 2014-10-31    156.60        7.69

# %%
returns = (1 + df_monthly.pct_change(1))

# %%
mul = 1
for each in RE['2014-09-30':]:
    mul = mul * each
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7c4f371969b4> in <module>
#       1 mul = 1
# ----> 2 for each in RE['2014-09-30':]:
#       3     mul = mul * each
#
# NameError: name 'RE' is not defined

# %%
mul**(1/LEND)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-8fcebba1c7d5> in <module>
# ----> 1 mul**(1/LEND)
#
# NameError: name 'LEND' is not defined

# %%
returns
# Out:
#             NORTHERN  ZEALBANGLA
# date
# 2014-01-31       NaN         NaN
# 2014-02-28  1.074943    0.975364
# 2014-03-31  1.113239    1.040184
# 2014-04-30  1.477859    1.035320
# 2014-05-31  1.147162    0.959488
# ...              ...         ...
# 2019-04-30  1.006010    1.047898
# 2019-05-31  0.965488    0.984002
# 2019-06-30  0.928776    1.006194
# 2019-07-31  0.913987    0.886894
# 2019-08-31  1.106962    0.955176
#
# [68 rows x 2 columns]

# %%
returns.cumprod(axis=None, skipna=True).iloc[-1]
# Out:
# NORTHERN      17.014534
# ZEALBANGLA     3.698768
# Name: 2019-08-31 00:00:00, dtype: float64

# %%
annual_return = ((1+df_asset.pct_change(1)).cumprod().iloc[-1])**(252/len(df_asset)) - 1

# %%
annual_return
# Out:
# KAY&QUE       0.596248
# SAVAREFR      0.127571
# ZEALBANGLA    0.330006
# NORTHERN      0.764008
# LEGACYFOOT    0.222912
# STANCERAM     0.580842
# MONNOCERA     0.429329
# DULAMIACOT    0.410419
# BDAUTOCA      0.474356
# Name: 2019-08-29 00:00:00, dtype: float64

# %%
annual_std = df_asset.pct_change(1).std()*math.sqrt(252)

# %%
annual_std
# Out:
# KAY&QUE       0.576079
# SAVAREFR      0.673550
# ZEALBANGLA    0.643682
# NORTHERN      0.579969
# LEGACYFOOT    0.579605
# STANCERAM     0.512121
# MONNOCERA     0.550103
# DULAMIACOT    0.661153
# BDAUTOCA      0.598457
# dtype: float64

# %%
sharpe_ratio = ((annual_return - .09 )/annual_std).sort_values(ascending = False)

# %%
sharpe_ratio
# Out:
# NORTHERN      1.162145
# STANCERAM     0.958450
# KAY&QUE       0.878783
# BDAUTOCA      0.642246
# MONNOCERA     0.616846
# DULAMIACOT    0.484637
# ZEALBANGLA    0.372864
# LEGACYFOOT    0.229315
# SAVAREFR      0.055780
# dtype: float64

# %%
df_cal.head()
# Out:
#                 symbol   open   high   low  close  volume
# date
# 2014-01-01   CONTININS   29.4   29.7  29.2   29.4   42500
# 2014-01-01   SEBL1STMF    8.0    8.1   7.9    7.9  178500
# 2014-01-01      BANGAS  483.0  483.7   480  480.2   31550
# 2014-01-01  ACTIVEFINE   82.2   86.6  82.2   86.4  322500
# 2014-01-01   ACIZCBOND  910.0  912.5   910  911.0      20

# %%
asset_desc = pd.pivot_table(df_cal, values='close', index='date', columns='symbol').drop('AZIZPIPES', axis=1)

# %%
asset_desc.head()
# Out:
# symbol      00DS30  00DSES   00DSEX  01.Bank  02.Cement  03.Ceramics_Sector  \
# date
# 2014-01-01     NaN     NaN  4286.15      NaN        NaN                 NaN
# 2014-01-02     NaN     NaN  4314.09      NaN        NaN                 NaN
# 2014-01-06     NaN     NaN  4296.34      NaN        NaN                 NaN
# 2014-01-07     NaN     NaN  4330.63      NaN        NaN                 NaN
# 2014-01-08     NaN     NaN  4391.27      NaN        NaN                 NaN
#
# symbol      04.Engineering  05.Financial_Institutions  06.Food_&_Allied  \
# date
# 2014-01-01             NaN                        NaN               NaN
# 2014-01-02             NaN                        NaN               NaN
# 2014-01-06             NaN                        NaN               NaN
# 2014-01-07             NaN                        NaN               NaN
# 2014-01-08             NaN                        NaN               NaN
#
# symbol      07.Fuel_&_Power  ...  UTTARAFIN  VAMLBDMF1  VAMLRBBF  VFSTDL  \
# date                         ...
# 2014-01-01              NaN  ...       86.0        NaN       NaN     NaN
# 2014-01-02              NaN  ...       86.1        NaN       NaN     NaN
# 2014-01-06              NaN  ...       84.7        NaN       NaN     NaN
# 2014-01-07              NaN  ...       84.0        NaN       NaN     NaN
# 2014-01-08              NaN  ...       85.6        NaN       NaN     NaN
#
# symbol      WATACHEM  WMSHIPYARD  YPL  ZAHEENSPIN  ZAHINTEX  ZEALBANGLA
# date
# 2014-01-01       NaN         NaN  NaN         NaN      27.2         NaN
# 2014-01-02       NaN         NaN  NaN         NaN      27.3         7.4
# 2014-01-06       NaN         NaN  NaN         NaN      27.1         7.8
# 2014-01-07       NaN         NaN  NaN         NaN      27.3         8.0
# 2014-01-08       NaN         NaN  NaN         NaN      27.8         8.1
#
# [5 rows x 415 columns]

# %%
annual_return_all = (((1+asset_desc.pct_change(1)).cumprod().iloc[-1])**(252/len(asset_desc)) - 1)

# %%
annual_return_all
# Out:
# symbol
# 00DS30       -0.004351
# 00DSES        0.001473
# 00DSEX        0.032386
# 01.Bank      -0.031792
# 02.Cement    -0.084807
#                 ...
# WMSHIPYARD   -0.226054
# YPL          -0.181798
# ZAHEENSPIN   -0.172389
# ZAHINTEX     -0.213210
# ZEALBANGLA    0.314843
# Name: 2019-08-29 00:00:00, Length: 415, dtype: float64

# %%
annual_std_all = asset_desc.pct_change(1).std()*math.sqrt(252)

# %%
annual_std_all
# Out:
# symbol
# 00DS30        0.106335
# 00DSES        0.098776
# 00DSEX        0.107512
# 01.Bank       0.356267
# 02.Cement     0.690591
#                 ...
# WMSHIPYARD    0.425022
# YPL           0.415037
# ZAHEENSPIN    0.425252
# ZAHINTEX      0.369259
# ZEALBANGLA    0.627451
# Length: 415, dtype: float64

# %%
sharpe_ratio_all = ((annual_return_all - .09 )/annual_std_all).sort_values(ascending = False)

# %%
top_symbols = sharpe_ratio_all[:20]
top_symbols
# Out:
# symbol
# NORTHERN      1.155803
# RENWICKJA     0.989896
# STANCERAM     0.908595
# KAY&QUE       0.844263
# AZIZPIPES     0.734045
# BDAUTOCA      0.617676
# MONNOCERA     0.591063
# DAFODILCOM    0.499538
# DULAMIACOT    0.463778
# RECKITTBEN    0.454843
# MONNOSTAF     0.449720
# EASTRNLUB     0.437390
# PHARMAID      0.427485
# SONALIANSH    0.392770
# ZEALBANGLA    0.358344
# UPGDCL        0.354040
# ECABLES       0.353783
# MODERNDYE     0.317913
# MARICO        0.317704
# IBNSINA       0.273937
# dtype: float64

# %%
top_sym = top_symbols.index.array
top_sym
# Out:
# <PandasArray>
# [  'NORTHERN',  'RENWICKJA',  'STANCERAM',    'KAY&QUE', 'AZIZPIPES ',
#    'BDAUTOCA',  'MONNOCERA', 'DAFODILCOM', 'DULAMIACOT', 'RECKITTBEN',
#   'MONNOSTAF',  'EASTRNLUB',   'PHARMAID', 'SONALIANSH', 'ZEALBANGLA',
#      'UPGDCL',    'ECABLES',  'MODERNDYE',     'MARICO',    'IBNSINA']
# Length: 20, dtype: object

# %%
asset_risky = asset_desc[top_sym]

# %%
asset_risky.head()
# Out:
# symbol      NORTHERN  RENWICKJA  STANCERAM  KAY&QUE  AZIZPIPES   BDAUTOCA  \
# date
# 2014-01-01      60.1      138.0       38.0     16.8         NaN      27.9
# 2014-01-02      62.2      138.2       39.9     17.3         NaN      27.7
# 2014-01-06       NaN      142.1       37.2     17.0         NaN      28.9
# 2014-01-07      62.2      143.8       38.5     17.5         NaN      30.5
# 2014-01-08      62.4      143.6       38.1     17.7         NaN      29.8
#
# symbol      MONNOCERA  DAFODILCOM  DULAMIACOT  RECKITTBEN  MONNOSTAF  \
# date
# 2014-01-01       33.4        13.5         7.9         NaN      294.5
# 2014-01-02       33.3        13.6         8.0         NaN      290.0
# 2014-01-06       33.0        13.5         8.3         NaN      290.8
# 2014-01-07       33.1        13.5         8.4         NaN      298.8
# 2014-01-08       33.3        13.5         8.7         NaN      308.6
#
# symbol      EASTRNLUB  PHARMAID  SONALIANSH  ZEALBANGLA  UPGDCL  ECABLES  \
# date
# 2014-01-01        NaN     158.9       129.6         NaN     NaN     82.6
# 2014-01-02      307.5     160.9       128.0         7.4     NaN     83.6
# 2014-01-06      303.2     160.8       127.7         7.8     NaN     88.8
# 2014-01-07      308.0     162.8       128.9         8.0     NaN     89.6
# 2014-01-08        NaN     162.8       129.9         8.1     NaN     87.3
#
# symbol      MODERNDYE  MARICO  IBNSINA
# date
# 2014-01-01       80.8   745.7    104.6
# 2014-01-02        NaN   754.9    103.0
# 2014-01-06       78.0   782.0    102.4
# 2014-01-07       79.7   783.5    102.6
# 2014-01-08       85.5   801.6    104.5

# %%
plt.figure(figsize=(20,20))
sns.heatmap(asset_risky.pct_change(1).corr())

# %%
asset_risky.pct_change(1).corr()
# Out:
# symbol      NORTHERN  RENWICKJA  STANCERAM   KAY&QUE  AZIZPIPES   BDAUTOCA  \
# symbol
# NORTHERN    1.000000   0.206601   0.048930  0.097776    0.088822  0.079143
# RENWICKJA   0.206601   1.000000   0.094715  0.086795    0.166276  0.136684
# STANCERAM   0.048930   0.094715   1.000000  0.105562    0.058307  0.126916
# KAY&QUE     0.097776   0.086795   0.105562  1.000000    0.143867  0.079315
# AZIZPIPES   0.088822   0.166276   0.058307  0.143867    1.000000  0.172227
# BDAUTOCA    0.079143   0.136684   0.126916  0.079315    0.172227  1.000000
# MONNOCERA   0.099728   0.212952   0.307997  0.112442    0.177269  0.190783
# DAFODILCOM  0.002407   0.016139   0.032822  0.089297    0.076034  0.106928
# DULAMIACOT  0.056472   0.029219   0.093922  0.117583    0.073864  0.044538
# RECKITTBEN  0.008199   0.104229  -0.051686  0.002080    0.055493  0.003120
# MONNOSTAF   0.148711   0.240381   0.088505  0.079207    0.077566  0.084022
# EASTRNLUB   0.133260   0.284923   0.058443  0.091233    0.125539  0.154577
# PHARMAID    0.159847   0.289694   0.084100  0.078954    0.111714  0.093924
# SONALIANSH  0.305406   0.338067   0.133196  0.152250    0.129347  0.170036
# ZEALBANGLA  0.037578   0.089199   0.052344  0.063198    0.074536  0.082016
# UPGDCL      0.009045   0.091551   0.014441  0.089427    0.015446  0.045914
# ECABLES     0.109325   0.232678   0.090337  0.069888    0.065493  0.091435
# MODERNDYE   0.076173   0.068550   0.013200  0.064329    0.039555  0.072290
# MARICO      0.016590   0.064683  -0.008800  0.036221    0.071824  0.003339
# IBNSINA     0.000825   0.160372   0.052562  0.072614    0.108266  0.083642
#
# symbol      MONNOCERA  DAFODILCOM  DULAMIACOT  RECKITTBEN  MONNOSTAF  \
# symbol
# NORTHERN     0.099728    0.002407    0.056472    0.008199   0.148711
# RENWICKJA    0.212952    0.016139    0.029219    0.104229   0.240381
# STANCERAM    0.307997    0.032822    0.093922   -0.051686   0.088505
# KAY&QUE      0.112442    0.089297    0.117583    0.002080   0.079207
# AZIZPIPES    0.177269    0.076034    0.073864    0.055493   0.077566
# BDAUTOCA     0.190783    0.106928    0.044538    0.003120   0.084022
# MONNOCERA    1.000000    0.043547    0.099204    0.030742   0.359729
# DAFODILCOM   0.043547    1.000000    0.029137   -0.034941   0.016145
# DULAMIACOT   0.099204    0.029137    1.000000    0.016162   0.020499
# RECKITTBEN   0.030742   -0.034941    0.016162    1.000000   0.033387
# MONNOSTAF    0.359729    0.016145    0.020499    0.033387   1.000000
# EASTRNLUB    0.123261    0.020022    0.000876    0.084674   0.190908
# PHARMAID     0.183562    0.035114    0.046781    0.065750   0.156246
# SONALIANSH   0.182819    0.075113    0.039487    0.087178   0.155958
# ZEALBANGLA   0.099591    0.033638    0.163440    0.005083   0.057476
# UPGDCL       0.011615    0.037867    0.048536    0.014197   0.010233
# ECABLES      0.121693    0.046743    0.023509    0.080408   0.142381
# MODERNDYE    0.033960    0.057705    0.041656    0.019125   0.038913
# MARICO      -0.022263    0.001162   -0.024712    0.272707   0.049488
# IBNSINA      0.089877    0.025237    0.040717    0.076842   0.095022
#
# symbol      EASTRNLUB  PHARMAID  SONALIANSH  ZEALBANGLA    UPGDCL   ECABLES  \
# symbol
# NORTHERN     0.133260  0.159847    0.305406    0.037578  0.009045  0.109325
# RENWICKJA    0.284923  0.289694    0.338067    0.089199  0.091551  0.232678
# STANCERAM    0.058443  0.084100    0.133196    0.052344  0.014441  0.090337
# KAY&QUE      0.091233  0.078954    0.152250    0.063198  0.089427  0.069888
# AZIZPIPES    0.125539  0.111714    0.129347    0.074536  0.015446  0.065493
# BDAUTOCA     0.154577  0.093924    0.170036    0.082016  0.045914  0.091435
# MONNOCERA    0.123261  0.183562    0.182819    0.099591  0.011615  0.121693
# DAFODILCOM   0.020022  0.035114    0.075113    0.033638  0.037867  0.046743
# DULAMIACOT   0.000876  0.046781    0.039487    0.163440  0.048536  0.023509
# RECKITTBEN   0.084674  0.065750    0.087178    0.005083  0.014197  0.080408
# MONNOSTAF    0.190908  0.156246    0.155958    0.057476  0.010233  0.142381
# EASTRNLUB    1.000000  0.177327    0.199697    0.060716  0.007158  0.109504
# PHARMAID     0.177327  1.000000    0.362185    0.080323  0.080049  0.198266
# SONALIANSH   0.199697  0.362185    1.000000    0.074696  0.046809  0.246528
# ZEALBANGLA   0.060716  0.080323    0.074696    1.000000  0.039886  0.055824
# UPGDCL       0.007158  0.080049    0.046809    0.039886  1.000000  0.056597
# ECABLES      0.109504  0.198266    0.246528    0.055824  0.056597  1.000000
# MODERNDYE    0.027534  0.072987    0.090243    0.016698 -0.050525  0.025282
# MARICO       0.106060  0.016403    0.031461   -0.002006  0.067922  0.066415
# IBNSINA      0.070914  0.164640    0.134893    0.033464  0.073986  0.103154
#
# symbol      MODERNDYE    MARICO   IBNSINA
# symbol
# NORTHERN     0.076173  0.016590  0.000825
# RENWICKJA    0.068550  0.064683  0.160372
# STANCERAM    0.013200 -0.008800  0.052562
# KAY&QUE      0.064329  0.036221  0.072614
# AZIZPIPES    0.039555  0.071824  0.108266
# BDAUTOCA     0.072290  0.003339  0.083642
# MONNOCERA    0.033960 -0.022263  0.089877
# DAFODILCOM   0.057705  0.001162  0.025237
# DULAMIACOT   0.041656 -0.024712  0.040717
# RECKITTBEN   0.019125  0.272707  0.076842
# MONNOSTAF    0.038913  0.049488  0.095022
# EASTRNLUB    0.027534  0.106060  0.070914
# PHARMAID     0.072987  0.016403  0.164640
# SONALIANSH   0.090243  0.031461  0.134893
# ZEALBANGLA   0.016698 -0.002006  0.033464
# UPGDCL      -0.050525  0.067922  0.073986
# ECABLES      0.025282  0.066415  0.103154
# MODERNDYE    1.000000  0.021511  0.090205
# MARICO       0.021511  1.000000  0.081412
# IBNSINA      0.090205  0.081412  1.000000

# %%
sharpe_ratio_all['MARICO']
# Out:
# 0.3177039672418867

# %%
asset_risky.pct_change(1).cov()
# Out:
# symbol          NORTHERN  RENWICKJA  STANCERAM   KAY&QUE  AZIZPIPES   \
# symbol
# NORTHERN    1.194806e-03   0.000214   0.000054  0.000120    0.000098
# RENWICKJA   2.144330e-04   0.000902   0.000091  0.000093    0.000154
# STANCERAM   5.417444e-05   0.000091   0.001026  0.000120    0.000061
# KAY&QUE     1.201655e-04   0.000093   0.000120  0.001264    0.000165
# AZIZPIPES   9.758554e-05   0.000154   0.000061  0.000165    0.001034
# BDAUTOCA    1.008635e-04   0.000151   0.000150  0.000104    0.000214
# MONNOCERA   1.171803e-04   0.000217   0.000335  0.000136    0.000205
# DAFODILCOM  2.066133e-06   0.000012   0.000026  0.000079    0.000060
# DULAMIACOT  7.982059e-05   0.000036   0.000123  0.000171    0.000100
# RECKITTBEN  6.062439e-06   0.000067  -0.000035  0.000002    0.000035
# MONNOSTAF   1.885268e-04   0.000265   0.000104  0.000103    0.000095
# EASTRNLUB   1.335675e-04   0.000248   0.000054  0.000094    0.000118
# PHARMAID    1.333477e-04   0.000210   0.000065  0.000068    0.000086
# SONALIANSH  3.147107e-04   0.000303   0.000127  0.000161    0.000124
# ZEALBANGLA  5.134294e-05   0.000106   0.000066  0.000089    0.000098
# UPGDCL      6.966668e-06   0.000061   0.000011  0.000074    0.000012
# ECABLES     1.067787e-04   0.000197   0.000082  0.000070    0.000059
# MODERNDYE   1.060208e-04   0.000083   0.000017  0.000092    0.000053
# MARICO      1.037501e-05   0.000035  -0.000005  0.000023    0.000037
# IBNSINA     6.005151e-07   0.000101   0.000035  0.000054    0.000074
#
# symbol      BDAUTOCA  MONNOCERA    DAFODILCOM  DULAMIACOT  RECKITTBEN  \
# symbol
# NORTHERN    0.000101   0.000117  2.066133e-06    0.000080    0.000006
# RENWICKJA   0.000151   0.000217  1.203609e-05    0.000036    0.000067
# STANCERAM   0.000150   0.000335  2.611097e-05    0.000123   -0.000035
# KAY&QUE     0.000104   0.000136  7.885344e-05    0.000171    0.000002
# AZIZPIPES   0.000214   0.000205  5.994782e-05    0.000100    0.000035
# BDAUTOCA    0.001359   0.000239  9.791531e-05    0.000067    0.000002
# MONNOCERA   0.000239   0.001156  3.676450e-05    0.000138    0.000022
# DAFODILCOM  0.000098   0.000037  6.168331e-04    0.000030   -0.000019
# DULAMIACOT  0.000067   0.000138  2.959150e-05    0.001672    0.000014
# RECKITTBEN  0.000002   0.000022 -1.862713e-05    0.000014    0.000458
# MONNOSTAF   0.000114   0.000448  1.470596e-05    0.000031    0.000026
# EASTRNLUB   0.000165   0.000122  1.442375e-05    0.000001    0.000053
# PHARMAID    0.000084   0.000151  2.104752e-05    0.000046    0.000034
# SONALIANSH  0.000187   0.000185  5.561399e-05    0.000048    0.000056
# ZEALBANGLA  0.000120   0.000134  3.303297e-05    0.000264    0.000004
# UPGDCL      0.000042   0.000010  2.160711e-05    0.000048    0.000006
# ECABLES     0.000095   0.000117  3.280298e-05    0.000027    0.000049
# MODERNDYE   0.000107   0.000046  5.770791e-05    0.000069    0.000016
# MARICO      0.000002  -0.000014  5.221909e-07   -0.000018    0.000106
# IBNSINA     0.000065   0.000064  1.320447e-05    0.000035    0.000035
#
# symbol      MONNOSTAF  EASTRNLUB  PHARMAID  SONALIANSH  ZEALBANGLA    UPGDCL  \
# symbol
# NORTHERN     0.000189   0.000134  0.000133    0.000315    0.000051  0.000007
# RENWICKJA    0.000265   0.000248  0.000210    0.000303    0.000106  0.000061
# STANCERAM    0.000104   0.000054  0.000065    0.000127    0.000066  0.000011
# KAY&QUE      0.000103   0.000094  0.000068    0.000161    0.000089  0.000074
# AZIZPIPES    0.000095   0.000118  0.000086    0.000124    0.000098  0.000012
# BDAUTOCA     0.000114   0.000165  0.000084    0.000187    0.000120  0.000042
# MONNOCERA    0.000448   0.000122  0.000151    0.000185    0.000134  0.000010
# DAFODILCOM   0.000015   0.000014  0.000021    0.000056    0.000033  0.000022
# DULAMIACOT   0.000031   0.000001  0.000046    0.000048    0.000264  0.000048
# RECKITTBEN   0.000026   0.000053  0.000034    0.000056    0.000004  0.000006
# MONNOSTAF    0.001345   0.000203  0.000138    0.000171    0.000083  0.000009
# EASTRNLUB    0.000203   0.000841  0.000124    0.000173    0.000070  0.000005
# PHARMAID     0.000138   0.000124  0.000582    0.000261    0.000077  0.000044
# SONALIANSH   0.000171   0.000173  0.000261    0.000889    0.000088  0.000032
# ZEALBANGLA   0.000083   0.000070  0.000077    0.000088    0.001562  0.000038
# UPGDCL       0.000009   0.000005  0.000044    0.000032    0.000038  0.000530
# ECABLES      0.000148   0.000090  0.000135    0.000208    0.000062  0.000037
# MODERNDYE    0.000057   0.000032  0.000071    0.000108    0.000027 -0.000049
# MARICO       0.000033   0.000056  0.000007    0.000017   -0.000001  0.000025
# IBNSINA      0.000073   0.000043  0.000084    0.000085    0.000028  0.000037
#
# symbol       ECABLES  MODERNDYE        MARICO       IBNSINA
# symbol
# NORTHERN    0.000107   0.000106  1.037501e-05  6.005151e-07
# RENWICKJA   0.000197   0.000083  3.513877e-05  1.014462e-04
# STANCERAM   0.000082   0.000017 -5.099761e-06  3.546817e-05
# KAY&QUE     0.000070   0.000092  2.329914e-05  5.438928e-05
# AZIZPIPES   0.000059   0.000053  3.678329e-05  7.399761e-05
# BDAUTOCA    0.000095   0.000107  2.227562e-06  6.496742e-05
# MONNOCERA   0.000117   0.000046 -1.369134e-05  6.436194e-05
# DAFODILCOM  0.000033   0.000058  5.221909e-07  1.320447e-05
# DULAMIACOT  0.000027   0.000069 -1.828170e-05  3.507518e-05
# RECKITTBEN  0.000049   0.000016  1.057099e-04  3.468746e-05
# MONNOSTAF   0.000148   0.000057  3.283698e-05  7.341780e-05
# EASTRNLUB   0.000090   0.000032  5.564954e-05  4.332317e-05
# PHARMAID    0.000135   0.000071  7.161864e-06  8.370721e-05
# SONALIANSH  0.000208   0.000108  1.696825e-05  8.471678e-05
# ZEALBANGLA  0.000062   0.000027 -1.434519e-06  2.786873e-05
# UPGDCL      0.000037  -0.000049  2.485324e-05  3.652775e-05
# ECABLES     0.000798   0.000029  3.395241e-05  6.140440e-05
# MODERNDYE   0.000029   0.001621  1.567071e-05  7.651881e-05
# MARICO      0.000034   0.000016  3.273167e-04  3.102888e-05
# IBNSINA     0.000061   0.000077  3.102888e-05  4.438045e-04

# %%
sharpe_ratio_all.head(50)
# Out:
# symbol
# NORTHERN              1.155803
# RENWICKJA             0.989896
# STANCERAM             0.908595
# KAY&QUE               0.844263
# AZIZPIPES             0.734045
# BDAUTOCA              0.617676
# MONNOCERA             0.591063
# DAFODILCOM            0.499538
# DULAMIACOT            0.463778
# RECKITTBEN            0.454843
# MONNOSTAF             0.449720
# EASTRNLUB             0.437390
# PHARMAID              0.427485
# SONALIANSH            0.392770
# ZEALBANGLA            0.358344
# UPGDCL                0.354040
# ECABLES               0.353783
# MODERNDYE             0.317913
# MARICO                0.317704
# IBNSINA               0.273937
# ANWARGALV             0.264529
# DSHGARME              0.256271
# LINDEBD               0.244935
# SINOBANGLA            0.237359
# SHYAMPSUG             0.234326
# SAMATALETH            0.226063
# LEGACYFOOT            0.215688
# DBH                   0.205641
# JMISMDL               0.204583
# AMBEEPHA              0.189837
# MTB                   0.188719
# IMAMBUTTON            0.170129
# RAHIMAFOOD            0.153872
# LIBRAINFU             0.148472
# WATACHEM              0.144654
# SPCL                  0.131505
# 03.Ceramics_Sector    0.122230
# BEACONPHAR            0.119694
# GLAXOSMITH            0.115657
# NPOLYMAR              0.111418
# 10.Jute               0.096298
# ACIFORMULA            0.092355
# 3RDICB                0.088807
# BXPHARMA              0.084772
# BRACBANK              0.079922
# BERGERPBL             0.058308
# 1STICB                0.057257
# SAVAREFR              0.048349
# APEXSPINN             0.047674
# NTLTUBES              0.042859
# dtype: float64

# %%
annual_rss = pd.DataFrame({'Returns': annual_return_all, 'Standard Dev': annual_std_all, 'Sharpe Ratio': sharpe_ratio_all})

# %%
annual_rss.sort_values('Sharpe Ratio', ascending= False).head(50).to_clipboard()

# %%
(197/17)**(1/5)
# Out:
# 1.6323130809104167

# %%
weights = pd.Series(np.arange(0,1.01,.01))
weights
# Out:
# 0      0.00
# 1      0.01
# 2      0.02
# 3      0.03
# 4      0.04
#        ...
# 96     0.96
# 97     0.97
# 98     0.98
# 99     0.99
# 100    1.00
# Length: 101, dtype: float64

# %%
assets_array = ['RENWICKJA','STANCERAM']
port_assets = annual_rss.loc[assets_array, :]
port_assets
# Out:
#             Returns  Standard Dev  Sharpe Ratio
# RENWICKJA  0.561847      0.476663      0.989896
# STANCERAM  0.552001      0.508479      0.908595

# %%
returns_assets = port_assets['Returns']
returns_assets
# Out:
# RENWICKJA    0.561847
# STANCERAM    0.552001
# Name: Returns, dtype: float64

# %%
cov = round(asset_risky[assets_array].pct_change(1).cov().loc[assets_array[0], assets_array[1]], 5)
cov
# Out:
# 9e-05

# %%
port_df = pd.DataFrame(columns = ['Weights R', 'Weights S', 'Portfolio Return', 'Portfolio Std', 'Portfolio Sharpe Ratio' ])
returns_assets = port_assets['Returns']
std_assets = port_assets['Standard Dev']
cov = asset_risky[assets_array].pct_change(1).cov().loc[assets_array[0], assets_array[1]]
risk_free = .09
for each in weights:
    port_return = each*returns_assets[0]+(1 - each)*returns_assets[1]
    port_std = (each*std_assets[0])**2 + ((1-each)*std_assets[1])**2 + 2*each*(1-each)*cov 
    port_shrp = (port_return - risk_free ) / port_std
    port_df = port_df.append({'Weights R': each, 'Weights S': 1 - each, 'Portfolio Return': port_return, 'Portfolio Std': port_std, 'Portfolio Sharpe Ratio': port_shrp}, ignore_index=True)
port_df.to_clipboard()
port_df
# Out:
#      Weights R  Weights S  Portfolio Return  Portfolio Std  \
# 0         0.00       1.00          0.552001       0.258551
# 1         0.01       0.99          0.552100       0.253430
# 2         0.02       0.98          0.552198       0.248407
# 3         0.03       0.97          0.552297       0.243480
# 4         0.04       0.96          0.552395       0.238651
# ..         ...        ...               ...            ...
# 96        0.96       0.04          0.561453       0.209816
# 97        0.97       0.03          0.561552       0.214018
# 98        0.98       0.02          0.561650       0.218318
# 99        0.99       0.01          0.561749       0.222714
# 100       1.00       0.00          0.561847       0.227208
#
#      Portfolio Sharpe Ratio
# 0                  1.786888
# 1                  1.823381
# 2                  1.860651
# 3                  1.898703
# 4                  1.937537
# ..                      ...
# 96                 2.246989
# 97                 2.203328
# 98                 2.160386
# 99                 2.118180
# 100                2.076719
#
# [101 rows x 5 columns]

# %%
port_df.sort_values('Portfolio Sharpe Ratio', ascending= False)
# Out:
#     Weights R  Weights S  Portfolio Return  Portfolio Std  \
# 53       0.53       0.47          0.557220       0.120982
# 54       0.54       0.46          0.557318       0.121008
# 52       0.52       0.48          0.557121       0.121053
# 55       0.55       0.45          0.557417       0.121132
# 51       0.51       0.49          0.557023       0.121220
# ..        ...        ...               ...            ...
# 4        0.04       0.96          0.552395       0.238651
# 3        0.03       0.97          0.552297       0.243480
# 2        0.02       0.98          0.552198       0.248407
# 1        0.01       0.99          0.552100       0.253430
# 0        0.00       1.00          0.552001       0.258551
#
#     Portfolio Sharpe Ratio
# 53                3.861894
# 54                3.861863
# 52                3.858827
# 55                3.858735
# 51                3.852675
# ..                     ...
# 4                 1.937537
# 3                 1.898703
# 2                 1.860651
# 1                 1.823381
# 0                 1.786888
#
# [101 rows x 5 columns]

# %%
plt.figure(figsize=(20, 20))
plt.ylim(0, .8)
plt.xlim(0,0.4)
plt.plot(port_df['Portfolio Std'], port_df['Portfolio Return'])
